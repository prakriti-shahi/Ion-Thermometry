# %% [markdown]
# # Ion Thermometry #

# %% [markdown]
# For a qubit (ion) in a harmonic trap, we want to understand how different motional states effect flopping rates on the qubit carrier & motional sideband transitions. In particular for a thermal state, we deduce how comparing Rabi rates can be exploited as a temperature diagnostic.

# %% [markdown]
# ## Unity and Quantity Definitions ##

# %%
using Revise
using IonSim
using QuantumOptics: timeevolution, stochastic, Basis
